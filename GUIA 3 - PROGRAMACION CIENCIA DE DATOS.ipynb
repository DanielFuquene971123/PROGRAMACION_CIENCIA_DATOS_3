# %% [markdown]
# # GUIA 3 - PROGRAMACION CIENCIA DE DATOS
# ### integrantes:
# ### Mateo Duque
# ### Yenny Gonzalez
# ### Daniel Fuquene

# %% [markdown]
# ## **Lectura y concatenado de datos**

# %%
import pandas as pd

# Leer el archivos
df1 = pd.read_csv('datos_secop_I_modified.csv', sep=',')
df2 = pd.read_csv('datos_secov_II_modified.csv', sep=';', encoding='latin-1')

# %%
df1
# Out:
#      identificador_paa  codigo_entidad  \
# 0               303062        28500134
# 1               294652       205001279
# 2               259436       286571031
# 3               263541       205001191
# 4               298985       250226019
# ..                 ...             ...
# 995             271499       205001175
# 996             278692       218756025
# 997             322980       205842019
# 998             318983        24100125
# 999             298484       220011015
#
#                                         nombre_entidad  nit_entidad  anno_paa  \
# 0                   CASANARE  ESE HOSPITAL DE YOPAL !     891855029      2022
# 1    ANTIOQUIA  INSTITUCIN EDUCATIVA DBORA ARANGO P...    900196642      2022
# 2    PUTUMAYO  CENTRO EDUCATIVO RURAL SAUDITA  PUER...  846004233-5      2021
# 3    ANTIOQUIA  INSTITUCIN EDUCATIVA SAN CRISTBAL  ...    811017472      2021
# 4    META  CENTRO EDUCATIVO RURAL JOSE MARIA GUIOTH...  900134298-9      2022
# ..                                                 ...          ...       ...
# 995  ANTIOQUIA  INSTITUCIN EDUCATIVA SANTA ELENA  M...    811017836      2021
# 996                   CAQUET  CE PEÑAS BLANCAS  SOLANO    900155525      2021
# 997  ANTIOQUIA  PERSONERIA MUNICIPAL DE URAMITA  UR...  890984575-7      2022
# 998   HUILA  INSTITUCIN EDUCATIVA SANTA LIBRADA  NEIVA    891180005      2022
# 999  CESAR  INSTITUTO MUNICIPAL DE DEPORTES RECREAC...    812001531      2022
#
#                                      direccion_entidad telefono_entidad  \
# 0    Calle 15 N 795 Manzana L via marginal de la selva          6344699
# 1                                    Calle 118  103160          5294058
# 2                                       VEREDA SAUDITA       3208339785
# 3                                Carrera 131 No 65  07          4279180
# 4                       Vda Caney Medio Km2CumaralMeta       3013604535
# ..                                                 ...              ...
# 995                           KILOMETRO 15 SANTA ELENA          5381304
# 996                                VEREDA CAMPO ALEGRE       3209439424
# 997  -Calle 20 N 1734 Palacio Municipal  2 piso URA...     317 400 4524
# 998                      Cra 12 No 1612 B Neiva  Huila          8750407
# 999  CALLE 6 No 5  100 TARIMA DEL POLIDEPORTIVO DE ...          5662167
#
#                                        mision_y_vision  \
# 0    MisionEl Hospital Regional de la Orinoquia es ...
# 1    MISION La Institucin Educativa Dbora Arango de...
# 2    MISION El Centro Educativo Rural Saudita garan...
# 3                                                 2021
# 4                                                Misin
# ..                                                 ...
# 995  MISION Formamos a nios nias y jvenes apoyados ...
# 996  MISION La IER Campo Alegre ofrece a todos los ...
# 997   MISIN Continuar trabajando por y con la comun...
# 998  VISION Para el ao 2020 la Institucin Educativa...
# 999   MisinPromover y fomentar el deporte la recrea...
#
#                                perspectiva_estrategica  \
# 0    el Hospital Regional de la Orinoqua ESE se con...
# 1    Direccionar la Institucin para el logro del ho...
# 2                                                    0
# 3                               wwwiesancristobaleduco
# 4    Mejoramiento de la calidad educativa en la pre...
# ..                                                 ...
# 995  Un colegio  con un modelo de gestin certificad...
# 996  Ofrecer calidad educativa en cada sede de la i...
# 997  La Personera Municipal de Uramita acorde con l...
# 998  La Institucin Educativa Santa Librada de Neiva...
# 999  El INSTITUO MUNICIPAL DE DEPORTE RECREACION Y ...
#
#                                          info_contacto  \
# 0    Almacen Hospital Regional de la Orinoquia Cont...
# 1                         Carlos Enrique Rojas Sanchez
# 2                                           3208339785
# 3    La  Institucin  Educativa San Cristbal ofrece ...
# 4    LUIS FERNANDO ROJAS SALAZAR CC 17267322 Cargo ...
# ..                                                 ...
# 995                         SILVIA ELENA RENDON GARZON
# 996                       ELSY LUCIA GONZALEZ PALACIOS
# 997  Abdn Lpez suga Personero MunicipalTelfono 317 ...
# 998                  Nury Quintero Rodriguez  Pagadora
# 999  SUGEIDY VARGAS OSORIO  DIRECTORA  imdrecaguach...
#
#                                             ppto_total  \
# 0                                         126898133557
# 1                                            $84026639
# 2                                           $107700000
# 3    La Institucin educativa San Cristbal Lder en l...
# 4                                            $22500000
# ..                                                 ...
# 995                                           92111926
# 996    $15800000 QUINCE MILLONES OCHOCIENTOS MIL PESOS
# 997                                          $14500000
# 998                                          108416516
# 999                                        $1342639796
#
#                                   limite_menor_cuantia limite_minima_cuantia  \
# 0                                                  NaN                  $nan
# 1                                                    0              20000000
# 2                                            254387280             $25438728
# 3    JOSE CHARLES VELEZ BETANCURRectoriesancristoba...             159239220
# 4                                            280000000             $28000000
# ..                                                 ...                   ...
# 995                                           17556040             $24578456
# 996                                           20 SMMLV             $20 SMMLV
# 997                                          254387280             $25250000
# 998                                          245784840              24578484
# 999                                         $280000000              28000000
#
#        fecha_ultima_actualizacion             fecha_cargue  municipio_paa  \
# 0                        12/31/21  2022-01-31T11:53:47.000          Yopal
# 1                         12/1/21  2022-01-26T09:43:07.000       Medellín
# 2                        11/27/20  2021-01-28T02:34:58.000  Puerto Guzmán
# 3                       181705200  2021-01-29T04:15:31.000       Medellín
# 4                         12/2/21  2022-01-28T07:06:52.000        Cumaral
# ..                            ...                      ...            ...
# 995                      11/30/20  2021-01-31T08:01:37.000       Medellín
# 996  18 de diciembre del a¿o 2020  2021-04-15T10:49:31.000         Solano
# 997                       10/1/22  2022-11-29T11:31:24.000        Uramita
# 998           14 de Julio de 2022  2022-07-14T00:01:24.000          Neiva
# 999                    28/01/2022  2022-01-28T04:13:09.000      Aguachica
#
#     departamento_paa         localidad_paa  codigo_municipio
# 0           Casanare            PLAN UNICO             85001
# 1          Antioquia            UNICO PLAN              5001
# 2           Putumayo            UNICO PLAN             86571
# 3          Antioquia            UNICO PLAN              5001
# 4               Meta            UNICO PLAN             50226
# ..               ...                   ...               ...
# 995        Antioquia            UNICO PLAN              5001
# 996          Caquetá            UNICO PLAN             18756
# 997        Antioquia  PERSONERIA MUNICIPAL              5842
# 998            Huila                   PAA             41001
# 999            Cesar            UNICO PLAN             20011
#
# [1000 rows x 19 columns]

# %%
df2
# Out:
#     identificador_unico id_plan_anual_de_adquisiciones  anno  nit_entidad  \
# 0       CO1.APP.2041264           MarketplaceCO1538159  2024    721520377
# 1       CO1.APP.2041602           MarketplaceCO1538240  2024    718938582
# 2       CO1.APP.2041198           MarketplaceCO1538184  2024    703036004
# 3       CO1.APP.2041074           MarketplaceCO1538121  2024    723119863
# 4       CO1.APP.2041030           MarketplaceCO1415172  2024    705153815
# ..                  ...                            ...   ...          ...
# 995      CO1.APP.981003           MarketplaceCO1159012  2021  701433674-3
# 996     CO1.APP.1946556           MarketplaceCO1494508  2024  718596000-8
# 997     CO1.APP.1640158           MarketplaceCO1370463  2022  709879217-2
# 998     CO1.APP.1370001           MarketplaceCO1227734  2022    718687114
# 999     CO1.APP.1394310           MarketplaceCO1265954  2022    718933161
#
#                                         nombre_entidad  \
# 0      INSTITUCION EDUCATIVA AGROPECUARIA MAXIMO GOMEZ
# 1           INSTITUCION EDUCATIVA MUNICIPAL EL SOCORRO
# 2                                  MUNICIPIO LA DORADA
# 3                      COOAGUAS DE PUEBLO NUEVO E.S.P.
# 4                                MUNICIPIO DE LA PLATA
# ..                                                 ...
# 995  DEPARTAMENTO ADMINISTRATIVO DE LA DEFENSORIA D...
# 996                   INSTITUCION EDUCATIVA EL PARAMO*
# 997              CONTRALORIA DISTRITAL DE BUENAVENTURA
# 998    INSTITUCION EDUCATIVA LICEO MIGUEL ANTONIO CARO
# 999                  INSTITUCIÓN EDUCATIVA DON QUIJOTE
#
#                                          mision_vision  \
# 0    MISION 2023 2026 La Institucin Educativa Agrop...
# 1    MISION Brindar una formacin acadmica que forme...
# 2    La administracin municipal regir los destinos ...
# 3    MISION LA ADMINISTRACION PBLICA COOPERATIVA EM...
# 4    Gestionar servir a la comunidad promover el bi...
# ..                                                 ...
# 995  MISION Contribuir al mejoramiento de la calida...
# 996  MISION La institucin Educativa El Pramo es una...
# 997  Ejercer eficientemente la vigilancia de la ges...
# 998                                        No Definido
# 999  MISIN La Institucin Educativa Don Quijote del ...
#
#                                perspectiva_estrategica  \
# 0    Ser una institucin destacada por sus estrategi...
# 1    El proceso de formacin de los educandos debe e...
# 2    La Dorada ser un municipio competitivo y soste...
# 3    POLITICA DE CALIDAD Somos un organismo pblico ...
# 4    A travs de la implementacin del presente Plan ...
# ..                                                 ...
# 995  1Contribuir al incremento del uso goce y disfr...
# 996  La Institucin educativa EL PARAMO para el cump...
# 997  El Plan Anual de Adquisiciones es un documento...
# 998                                        No Definido
# 999  El principal objetivo del Plan Anual de Adquis...
#
#                    nombre_contacto telefono_contacto  \
# 0    MARIA EUGENIA LEDESMA LLANTEN        3104661182
# 1          RAFAEL BASTIDAS SANCHEZ        3136820189
# 2    JULIAN DAVID OLIVEROS SERRANO           8572013
# 3     CARLOS FERNANDO GERMAN CALAO        3127695263
# 4        CRISTINA HOLGUIN GRISALES        3223001245
# ..                             ...               ...
# 995  /CARLOS ALFONSO QUINTERO MENA      3822510 1032
# 996       HELI RAFAEL DAZA MATACEA        3113339424
# 997         VIVIANA GONZALEZ VIVAS        3178124179
# 998     HECTOR JAIME NARANJO RODAS        3185436690
# 999        ILLYAN HURTADO ZAMBRANO        3133900676
#
#                                   correo_contacto  ...  \
# 0                  mariaeugenia.maestra@gmail.com  ...
# 1                        rafabastidas@hotmail.com  ...
# 2                  compras@ladorada-caldas.gov.co  ...
# 3                        carlosgcalao@outlook.com  ...
# 4                    almacen@laplata-huila.gov.co  ...
# ..                                            ...  ...
# 995                        cquintero@dadep.gov.co  ...
# 996          ie.paramo.taminango@sednarino.gov.co  ...
# 997  talentohumano@contraloriabuenaventura.gov.co  ...
# 998        contratosmiguelantoniocaro@hotmail.com  ...
# 999                  iedonquijote_jos@hotmail.com  ...
#
#     presupuesto_menor_cuantia presupuesto_minima_cuantia  \
# 0                 $26000000.0                 $2600000.0
# 1                $845000000.0                $84500000.0
# 2                $364000000.0                $36400000.0
# 3                 174000000.0                116000000.0
# 4                $364000000.0                $36400000.0
# ..                        ...                        ...
# 995              $254387280.0                 25438728.0
# 996              1105000000.0                110500000.0
# 997               280000000.0                 28000000.0
# 998               280000000.0                 28000000.0
# 999               285000000.0                $28500000.0
#
#             fecha_de_publicacion            fecha_de_creacion  \
# 0    2024-07-31 03:47:42.6041815  2024-08-23 07:11:00.0000000
# 1    2024-01-31 16:19:08.5384812  2024-08-23 07:11:00.0000000
# 2    2024-01-17 20:54:03.3001599  2024-08-23 07:11:00.0000000
# 3    2024-02-01 02:01:48.3772533  2024-08-23 07:11:00.0000000
# 4    2024-01-10 15:55:50.6223556  2024-08-23 07:11:00.0000000
# ..                           ...                          ...
# 995  2021-01-14 13:56:08.3550442  2024-08-09 19:40:53.0000000
# 996  2024-02-01 00:22:06.6399269  2024-08-09 19:40:53.0000000
# 997  2022-02-08 22:14:35.2824387  2024-08-09 19:40:53.0000000
# 998  2022-09-29 14:58:23.4044464  2024-08-09 19:40:53.0000000
# 999  2022-12-30 14:54:06.5099342  2024-08-09 19:40:53.0000000
#
#       fecha_de_ultima_modificacion version  \
# 0    2024-08-22 20:32:26.391947400       2
# 1    2024-08-22 22:00:52.607658300      13
# 2    2024-08-22 21:03:45.672865800      28
# 3    2024-08-22 19:47:30.908245300       2
# 4    2024-08-22 15:48:03.701324800     148
# ..                             ...     ...
# 995  2021-09-07 17:48:04.020848600      23
# 996  2024-05-30 17:43:48.585691500       2
# 997  2023-08-17 22:50:41.294767000       7
# 998  2022-12-05 00:55:13.012865700       3
# 999    2024-08-09 19:40:53.0000000       1
#
#      identificador_requerimiento_compra           estado  \
# 0                      CO1.PPI.33807381         Borrador
# 1                      CO1.PPI.33809817  No especificado
# 2                      CO1.PPI.33808340         Borrador
# 3                      CO1.PPI.33805980         Borrador
# 4                      CO1.PPI.33799556        Publicado
# ..                                  ...              ...
# 995                    CO1.PPI.14941473  No especificado
# 996                    CO1.PPI.32140664         Aprobado
# 997                    CO1.PPI.26793161         Borrador
# 998                    CO1.PPI.22010955        Publicado
# 999                    CO1.PPI.22324720        Publicado
#
#                departamento_paa        municipio_paa
# 0                         Cauca              Cajibío
# 1                        Nariño                Pasto
# 2                        Caldas            La Dorada
# 3                       Córdoba         Pueblo Nuevo
# 4                         Huila             La Plata
# ..                          ...                  ...
# 995  Distrito Capital de Bogotá               Bogotá
# 996                      Nariño            Taminango
# 997             Valle del Cauca         Buenaventura
# 998                     Córdoba             Montería
# 999                     Caquetá  San José Del Fragua
#
# [1000 rows x 21 columns]

# %%
#Cambiar nombre de columnas de df1

df1.rename(columns={
    'nombre_entidad': 'Nombre Entidad',
    'nit_entidad': 'NIT',
    'anno_paa': 'Año',
    'ppto_total': 'Presupuesto Total',
    'limite_menor_cuantia': 'Limite Menor Cuantia',
    'limite_minima_cuantia': 'Limite Minima Cuantia',
    'fecha_ultima_actualizacion': 'Fecha ultima actualizacion',
    'fecha_cargue': 'Fecha de Cargue',
    'municipio_paa': 'Municipio',
    'departamento_paa': 'Departamento'
}, inplace=True)

print(df1)

#Cambiar nombres df2

df2.rename(columns={
    'nombre_entidad': 'Nombre Entidad',
    'nit_entidad': 'NIT',
    'anno': 'Año',
    'valor_presupuesto_general': 'Presupuesto Total',
    'presupuesto_menor_cuantia': 'Limite Menor Cuantia',
    'presupuesto_minima_cuantia': 'Limite Minima Cuantia',
    'fecha_de_ultima_modificacion': 'Fecha ultima actualizacion',
    'fecha_de_creacion': 'Fecha de Cargue',
    'municipio_paa': 'Municipio',
    'departamento_paa': 'Departamento'
}, inplace=True)
# Out:
#      identificador_paa  codigo_entidad  \
# 0               303062        28500134
# 1               294652       205001279
# 2               259436       286571031
# 3               263541       205001191
# 4               298985       250226019
# ..                 ...             ...
# 995             271499       205001175
# 996             278692       218756025
# 997             322980       205842019
# 998             318983        24100125
# 999             298484       220011015
#
#                                         Nombre Entidad          NIT   Año  \
# 0                   CASANARE  ESE HOSPITAL DE YOPAL !     891855029  2022
# 1    ANTIOQUIA  INSTITUCIN EDUCATIVA DBORA ARANGO P...    900196642  2022
# 2    PUTUMAYO  CENTRO EDUCATIVO RURAL SAUDITA  PUER...  846004233-5  2021
# 3    ANTIOQUIA  INSTITUCIN EDUCATIVA SAN CRISTBAL  ...    811017472  2021
# 4    META  CENTRO EDUCATIVO RURAL JOSE MARIA GUIOTH...  900134298-9  2022
# ..                                                 ...          ...   ...
# 995  ANTIOQUIA  INSTITUCIN EDUCATIVA SANTA ELENA  M...    811017836  2021
# 996                   CAQUET  CE PEÑAS BLANCAS  SOLANO    900155525  2021
# 997  ANTIOQUIA  PERSONERIA MUNICIPAL DE URAMITA  UR...  890984575-7  2022
# 998   HUILA  INSTITUCIN EDUCATIVA SANTA LIBRADA  NEIVA    891180005  2022
# 999  CESAR  INSTITUTO MUNICIPAL DE DEPORTES RECREAC...    812001531  2022
#
#                                      direccion_entidad telefono_entidad  \
# 0    Calle 15 N 795 Manzana L via marginal de la selva          6344699
# 1                                    Calle 118  103160          5294058
# 2                                       VEREDA SAUDITA       3208339785
# 3                                Carrera 131 No 65  07          4279180
# 4                       Vda Caney Medio Km2CumaralMeta       3013604535
# ..                                                 ...              ...
# 995                           KILOMETRO 15 SANTA ELENA          5381304
# 996                                VEREDA CAMPO ALEGRE       3209439424
# 997  -Calle 20 N 1734 Palacio Municipal  2 piso URA...     317 400 4524
# 998                      Cra 12 No 1612 B Neiva  Huila          8750407
# 999  CALLE 6 No 5  100 TARIMA DEL POLIDEPORTIVO DE ...          5662167
#
#                                        mision_y_vision  \
# 0    MisionEl Hospital Regional de la Orinoquia es ...
# 1    MISION La Institucin Educativa Dbora Arango de...
# 2    MISION El Centro Educativo Rural Saudita garan...
# 3                                                 2021
# 4                                                Misin
# ..                                                 ...
# 995  MISION Formamos a nios nias y jvenes apoyados ...
# 996  MISION La IER Campo Alegre ofrece a todos los ...
# 997   MISIN Continuar trabajando por y con la comun...
# 998  VISION Para el ao 2020 la Institucin Educativa...
# 999   MisinPromover y fomentar el deporte la recrea...
#
#                                perspectiva_estrategica  \
# 0    el Hospital Regional de la Orinoqua ESE se con...
# 1    Direccionar la Institucin para el logro del ho...
# 2                                                    0
# 3                               wwwiesancristobaleduco
# 4    Mejoramiento de la calidad educativa en la pre...
# ..                                                 ...
# 995  Un colegio  con un modelo de gestin certificad...
# 996  Ofrecer calidad educativa en cada sede de la i...
# 997  La Personera Municipal de Uramita acorde con l...
# 998  La Institucin Educativa Santa Librada de Neiva...
# 999  El INSTITUO MUNICIPAL DE DEPORTE RECREACION Y ...
#
#                                          info_contacto  \
# 0    Almacen Hospital Regional de la Orinoquia Cont...
# 1                         Carlos Enrique Rojas Sanchez
# 2                                           3208339785
# 3    La  Institucin  Educativa San Cristbal ofrece ...
# 4    LUIS FERNANDO ROJAS SALAZAR CC 17267322 Cargo ...
# ..                                                 ...
# 995                         SILVIA ELENA RENDON GARZON
# 996                       ELSY LUCIA GONZALEZ PALACIOS
# 997  Abdn Lpez suga Personero MunicipalTelfono 317 ...
# 998                  Nury Quintero Rodriguez  Pagadora
# 999  SUGEIDY VARGAS OSORIO  DIRECTORA  imdrecaguach...
#
#                                      Presupuesto Total  \
# 0                                         126898133557
# 1                                            $84026639
# 2                                           $107700000
# 3    La Institucin educativa San Cristbal Lder en l...
# 4                                            $22500000
# ..                                                 ...
# 995                                           92111926
# 996    $15800000 QUINCE MILLONES OCHOCIENTOS MIL PESOS
# 997                                          $14500000
# 998                                          108416516
# 999                                        $1342639796
#
#                                   Limite Menor Cuantia Limite Minima Cuantia  \
# 0                                                  NaN                  $nan
# 1                                                    0              20000000
# 2                                            254387280             $25438728
# 3    JOSE CHARLES VELEZ BETANCURRectoriesancristoba...             159239220
# 4                                            280000000             $28000000
# ..                                                 ...                   ...
# 995                                           17556040             $24578456
# 996                                           20 SMMLV             $20 SMMLV
# 997                                          254387280             $25250000
# 998                                          245784840              24578484
# 999                                         $280000000              28000000
#
#        Fecha ultima actualizacion          Fecha de Cargue      Municipio  \
# 0                        12/31/21  2022-01-31T11:53:47.000          Yopal
# 1                         12/1/21  2022-01-26T09:43:07.000       Medellín
# 2                        11/27/20  2021-01-28T02:34:58.000  Puerto Guzmán
# 3                       181705200  2021-01-29T04:15:31.000       Medellín
# 4                         12/2/21  2022-01-28T07:06:52.000        Cumaral
# ..                            ...                      ...            ...
# 995                      11/30/20  2021-01-31T08:01:37.000       Medellín
# 996  18 de diciembre del a¿o 2020  2021-04-15T10:49:31.000         Solano
# 997                       10/1/22  2022-11-29T11:31:24.000        Uramita
# 998           14 de Julio de 2022  2022-07-14T00:01:24.000          Neiva
# 999                    28/01/2022  2022-01-28T04:13:09.000      Aguachica
#
#     Departamento         localidad_paa  codigo_municipio
# 0       Casanare            PLAN UNICO             85001
# 1      Antioquia            UNICO PLAN              5001
# 2       Putumayo            UNICO PLAN             86571
# 3      Antioquia            UNICO PLAN              5001
# 4           Meta            UNICO PLAN             50226
# ..           ...                   ...               ...
# 995    Antioquia            UNICO PLAN              5001
# 996      Caquetá            UNICO PLAN             18756
# 997    Antioquia  PERSONERIA MUNICIPAL              5842
# 998        Huila                   PAA             41001
# 999        Cesar            UNICO PLAN             20011
#
# [1000 rows x 19 columns]

# %%
df1
# Out:
#      identificador_paa  codigo_entidad  \
# 0               303062        28500134
# 1               294652       205001279
# 2               259436       286571031
# 3               263541       205001191
# 4               298985       250226019
# ..                 ...             ...
# 995             271499       205001175
# 996             278692       218756025
# 997             322980       205842019
# 998             318983        24100125
# 999             298484       220011015
#
#                                         Nombre Entidad          NIT   Año  \
# 0                   CASANARE  ESE HOSPITAL DE YOPAL !     891855029  2022
# 1    ANTIOQUIA  INSTITUCIN EDUCATIVA DBORA ARANGO P...    900196642  2022
# 2    PUTUMAYO  CENTRO EDUCATIVO RURAL SAUDITA  PUER...  846004233-5  2021
# 3    ANTIOQUIA  INSTITUCIN EDUCATIVA SAN CRISTBAL  ...    811017472  2021
# 4    META  CENTRO EDUCATIVO RURAL JOSE MARIA GUIOTH...  900134298-9  2022
# ..                                                 ...          ...   ...
# 995  ANTIOQUIA  INSTITUCIN EDUCATIVA SANTA ELENA  M...    811017836  2021
# 996                   CAQUET  CE PEÑAS BLANCAS  SOLANO    900155525  2021
# 997  ANTIOQUIA  PERSONERIA MUNICIPAL DE URAMITA  UR...  890984575-7  2022
# 998   HUILA  INSTITUCIN EDUCATIVA SANTA LIBRADA  NEIVA    891180005  2022
# 999  CESAR  INSTITUTO MUNICIPAL DE DEPORTES RECREAC...    812001531  2022
#
#                                      direccion_entidad telefono_entidad  \
# 0    Calle 15 N 795 Manzana L via marginal de la selva          6344699
# 1                                    Calle 118  103160          5294058
# 2                                       VEREDA SAUDITA       3208339785
# 3                                Carrera 131 No 65  07          4279180
# 4                       Vda Caney Medio Km2CumaralMeta       3013604535
# ..                                                 ...              ...
# 995                           KILOMETRO 15 SANTA ELENA          5381304
# 996                                VEREDA CAMPO ALEGRE       3209439424
# 997  -Calle 20 N 1734 Palacio Municipal  2 piso URA...     317 400 4524
# 998                      Cra 12 No 1612 B Neiva  Huila          8750407
# 999  CALLE 6 No 5  100 TARIMA DEL POLIDEPORTIVO DE ...          5662167
#
#                                        mision_y_vision  \
# 0    MisionEl Hospital Regional de la Orinoquia es ...
# 1    MISION La Institucin Educativa Dbora Arango de...
# 2    MISION El Centro Educativo Rural Saudita garan...
# 3                                                 2021
# 4                                                Misin
# ..                                                 ...
# 995  MISION Formamos a nios nias y jvenes apoyados ...
# 996  MISION La IER Campo Alegre ofrece a todos los ...
# 997   MISIN Continuar trabajando por y con la comun...
# 998  VISION Para el ao 2020 la Institucin Educativa...
# 999   MisinPromover y fomentar el deporte la recrea...
#
#                                perspectiva_estrategica  \
# 0    el Hospital Regional de la Orinoqua ESE se con...
# 1    Direccionar la Institucin para el logro del ho...
# 2                                                    0
# 3                               wwwiesancristobaleduco
# 4    Mejoramiento de la calidad educativa en la pre...
# ..                                                 ...
# 995  Un colegio  con un modelo de gestin certificad...
# 996  Ofrecer calidad educativa en cada sede de la i...
# 997  La Personera Municipal de Uramita acorde con l...
# 998  La Institucin Educativa Santa Librada de Neiva...
# 999  El INSTITUO MUNICIPAL DE DEPORTE RECREACION Y ...
#
#                                          info_contacto  \
# 0    Almacen Hospital Regional de la Orinoquia Cont...
# 1                         Carlos Enrique Rojas Sanchez
# 2                                           3208339785
# 3    La  Institucin  Educativa San Cristbal ofrece ...
# 4    LUIS FERNANDO ROJAS SALAZAR CC 17267322 Cargo ...
# ..                                                 ...
# 995                         SILVIA ELENA RENDON GARZON
# 996                       ELSY LUCIA GONZALEZ PALACIOS
# 997  Abdn Lpez suga Personero MunicipalTelfono 317 ...
# 998                  Nury Quintero Rodriguez  Pagadora
# 999  SUGEIDY VARGAS OSORIO  DIRECTORA  imdrecaguach...
#
#                                      Presupuesto Total  \
# 0                                         126898133557
# 1                                            $84026639
# 2                                           $107700000
# 3    La Institucin educativa San Cristbal Lder en l...
# 4                                            $22500000
# ..                                                 ...
# 995                                           92111926
# 996    $15800000 QUINCE MILLONES OCHOCIENTOS MIL PESOS
# 997                                          $14500000
# 998                                          108416516
# 999                                        $1342639796
#
#                                   Limite Menor Cuantia Limite Minima Cuantia  \
# 0                                                  NaN                  $nan
# 1                                                    0              20000000
# 2                                            254387280             $25438728
# 3    JOSE CHARLES VELEZ BETANCURRectoriesancristoba...             159239220
# 4                                            280000000             $28000000
# ..                                                 ...                   ...
# 995                                           17556040             $24578456
# 996                                           20 SMMLV             $20 SMMLV
# 997                                          254387280             $25250000
# 998                                          245784840              24578484
# 999                                         $280000000              28000000
#
#        Fecha ultima actualizacion          Fecha de Cargue      Municipio  \
# 0                        12/31/21  2022-01-31T11:53:47.000          Yopal
# 1                         12/1/21  2022-01-26T09:43:07.000       Medellín
# 2                        11/27/20  2021-01-28T02:34:58.000  Puerto Guzmán
# 3                       181705200  2021-01-29T04:15:31.000       Medellín
# 4                         12/2/21  2022-01-28T07:06:52.000        Cumaral
# ..                            ...                      ...            ...
# 995                      11/30/20  2021-01-31T08:01:37.000       Medellín
# 996  18 de diciembre del a¿o 2020  2021-04-15T10:49:31.000         Solano
# 997                       10/1/22  2022-11-29T11:31:24.000        Uramita
# 998           14 de Julio de 2022  2022-07-14T00:01:24.000          Neiva
# 999                    28/01/2022  2022-01-28T04:13:09.000      Aguachica
#
#     Departamento         localidad_paa  codigo_municipio
# 0       Casanare            PLAN UNICO             85001
# 1      Antioquia            UNICO PLAN              5001
# 2       Putumayo            UNICO PLAN             86571
# 3      Antioquia            UNICO PLAN              5001
# 4           Meta            UNICO PLAN             50226
# ..           ...                   ...               ...
# 995    Antioquia            UNICO PLAN              5001
# 996      Caquetá            UNICO PLAN             18756
# 997    Antioquia  PERSONERIA MUNICIPAL              5842
# 998        Huila                   PAA             41001
# 999        Cesar            UNICO PLAN             20011
#
# [1000 rows x 19 columns]

# %% [markdown]
# # Columnas a concatenar de ambos dataframes.
#
# Identificamos y agrupamos en una variable las columnas que se relacionan entre ambas bases de datos distintivamente para posteriormente poder concatenarlas y asi poder realizar el analisis respectivo.

# %%
# Seleccion de columnas
columnas_df1 = ['Nombre Entidad', 'NIT', 'Año', 'Presupuesto Total', 'Limite Menor Cuantia', 'Limite Minima Cuantia', 'Fecha ultima actualizacion'
                , 'Fecha de Cargue', 'Municipio', 'Departamento']
columnas_df2 = ['Nombre Entidad', 'NIT', 'Año', 'Presupuesto Total', 'Limite Menor Cuantia', 'Limite Minima Cuantia', 'Fecha ultima actualizacion'
                , 'Fecha de Cargue', 'Municipio', 'Departamento']

df1_seleccionadas= df1[columnas_df1]
df2_seleccionadas = df2[columnas_df2]

# Concatenar DataFrames verticalmente (por defecto axis=0)
df3 = pd.concat([df1_seleccionadas, df2_seleccionadas],ignore_index=True)

# Mostrar las primeras filas del DataFrame combinado
df3.head()
# Out:
#                                       Nombre Entidad          NIT   Año  \
# 0                 CASANARE  ESE HOSPITAL DE YOPAL !     891855029  2022
# 1  ANTIOQUIA  INSTITUCIN EDUCATIVA DBORA ARANGO P...    900196642  2022
# 2  PUTUMAYO  CENTRO EDUCATIVO RURAL SAUDITA  PUER...  846004233-5  2021
# 3  ANTIOQUIA  INSTITUCIN EDUCATIVA SAN CRISTBAL  ...    811017472  2021
# 4  META  CENTRO EDUCATIVO RURAL JOSE MARIA GUIOTH...  900134298-9  2022
#
#                                    Presupuesto Total  \
# 0                                       126898133557
# 1                                          $84026639
# 2                                         $107700000
# 3  La Institucin educativa San Cristbal Lder en l...
# 4                                          $22500000
#
#                                 Limite Menor Cuantia Limite Minima Cuantia  \
# 0                                                NaN                  $nan
# 1                                                  0              20000000
# 2                                          254387280             $25438728
# 3  JOSE CHARLES VELEZ BETANCURRectoriesancristoba...             159239220
# 4                                          280000000             $28000000
#
#   Fecha ultima actualizacion          Fecha de Cargue      Municipio  \
# 0                   12/31/21  2022-01-31T11:53:47.000          Yopal
# 1                    12/1/21  2022-01-26T09:43:07.000       Medellín
# 2                   11/27/20  2021-01-28T02:34:58.000  Puerto Guzmán
# 3                  181705200  2021-01-29T04:15:31.000       Medellín
# 4                    12/2/21  2022-01-28T07:06:52.000        Cumaral
#
#   Departamento
# 0     Casanare
# 1    Antioquia
# 2     Putumayo
# 3    Antioquia
# 4         Meta

# %% [markdown]
# ## **Limpieza de datos**

# %%
#Limpieza de Nit
#Quitar espacios y guiones
df3['NIT'] = df3['NIT'].astype(str).str.replace(' ', '').str.replace('-', '')

# Ajustar los NITs: si tienen más de 9 caracteres, quitar los últimos caracteres
df3['NIT'] = df3['NIT'].apply(lambda x: x[:9] if len(x) > 9 else x)

# Contar el número de caracteres en cada NIT
df3['NIT_length'] = df3['NIT'].str.len()

print(df3['NIT_length'])
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 1995    9
# 1996    9
# 1997    9
# 1998    9
# 1999    9
# Name: NIT_length, Length: 2000, dtype: int64

# %%
df3['NIT'].str.len().unique() # Como podemos observar todos los NIT cumplen la caracteristica de tener 9 caracteres.
# Out:
# array([9], dtype=int64)

# %%
#Quitar signos de $ en columanas de montos
columnas_a_limpiar = ['Presupuesto Total', 'Limite Menor Cuantia', 'Limite Minima Cuantia']  # Reemplaza con los nombres de tus columnas

# Quitar los signos de pesos de las columnas especificadas
for columna in columnas_a_limpiar:
    df3[columna] = df3[columna].astype(str).str.replace('$', '').str.replace(',', '')
    
df3
# Out:
#                                          Nombre Entidad        NIT   Año  \
# 0                    CASANARE  ESE HOSPITAL DE YOPAL !   891855029  2022
# 1     ANTIOQUIA  INSTITUCIN EDUCATIVA DBORA ARANGO P...  900196642  2022
# 2     PUTUMAYO  CENTRO EDUCATIVO RURAL SAUDITA  PUER...  846004233  2021
# 3     ANTIOQUIA  INSTITUCIN EDUCATIVA SAN CRISTBAL  ...  811017472  2021
# 4     META  CENTRO EDUCATIVO RURAL JOSE MARIA GUIOTH...  900134298  2022
# ...                                                 ...        ...   ...
# 1995  DEPARTAMENTO ADMINISTRATIVO DE LA DEFENSORIA D...  701433674  2021
# 1996                   INSTITUCION EDUCATIVA EL PARAMO*  718596000  2024
# 1997              CONTRALORIA DISTRITAL DE BUENAVENTURA  709879217  2022
# 1998    INSTITUCION EDUCATIVA LICEO MIGUEL ANTONIO CARO  718687114  2022
# 1999                  INSTITUCIÓN EDUCATIVA DON QUIJOTE  718933161  2022
#
#                                       Presupuesto Total  \
# 0                                          126898133557
# 1                                              84026639
# 2                                             107700000
# 3     La Institucin educativa San Cristbal Lder en l...
# 4                                              22500000
# ...                                                 ...
# 1995                                      27027845416.0
# 1996                                         40200000.0
# 1997                                        899802000.0
# 1998                                         31902500.0
# 1999                                         64800000.0
#
#                                    Limite Menor Cuantia Limite Minima Cuantia  \
# 0                                                   nan                   nan
# 1                                                     0              20000000
# 2                                             254387280              25438728
# 3     JOSE CHARLES VELEZ BETANCURRectoriesancristoba...             159239220
# 4                                             280000000              28000000
# ...                                                 ...                   ...
# 1995                                        254387280.0            25438728.0
# 1996                                       1105000000.0           110500000.0
# 1997                                        280000000.0            28000000.0
# 1998                                        280000000.0            28000000.0
# 1999                                        285000000.0            28500000.0
#
#          Fecha ultima actualizacion              Fecha de Cargue  \
# 0                          12/31/21      2022-01-31T11:53:47.000
# 1                           12/1/21      2022-01-26T09:43:07.000
# 2                          11/27/20      2021-01-28T02:34:58.000
# 3                         181705200      2021-01-29T04:15:31.000
# 4                           12/2/21      2022-01-28T07:06:52.000
# ...                             ...                          ...
# 1995  2021-09-07 17:48:04.020848600  2024-08-09 19:40:53.0000000
# 1996  2024-05-30 17:43:48.585691500  2024-08-09 19:40:53.0000000
# 1997  2023-08-17 22:50:41.294767000  2024-08-09 19:40:53.0000000
# 1998  2022-12-05 00:55:13.012865700  2024-08-09 19:40:53.0000000
# 1999    2024-08-09 19:40:53.0000000  2024-08-09 19:40:53.0000000
#
#                 Municipio                Departamento  NIT_length
# 0                   Yopal                    Casanare           9
# 1                Medellín                   Antioquia           9
# 2           Puerto Guzmán                    Putumayo           9
# 3                Medellín                   Antioquia           9
# 4                 Cumaral                        Meta           9
# ...                   ...                         ...         ...
# 1995               Bogotá  Distrito Capital de Bogotá           9
# 1996            Taminango                      Nariño           9
# 1997         Buenaventura             Valle del Cauca           9
# 1998             Montería                     Córdoba           9
# 1999  San José Del Fragua                     Caquetá           9
#
# [2000 rows x 11 columns]

# %%
#Eliminar filas nulas
# Contar el número de filas antes de limpiar
num_filas_antes = len(df3)

#Quitar valores nulos y de texto de las columnas a limpiar
df3 = df3.dropna(subset=columnas_a_limpiar)

# Contar el número de filas después de limpiar
num_filas_despues = len(df3)

# Calcular el número de filas eliminadas
filas_eliminadas = num_filas_antes - num_filas_despues

# Mostrar el número de filas eliminadas
print(f'Número de filas eliminadas: {filas_eliminadas}')
# Out:
# Número de filas eliminadas: 0

# %% [markdown]
# # Determinar cuales son los datos que seran el medio a analizar
#
# Determinamos que el analisis de datos se realizara en las variables numericas y la limpieza se realiza en base a estas para todo el dataframe concatenado.

# %%
# Contar el número de filas
num_filas_antes = len(df3)

# Para almacenar las filas que no se pudieron convertir
filas_no_convertidas = pd.DataFrame()

# Intentar convertir las columnas a tipo numérico y detectar filas no convertibles
for columna in columnas_a_limpiar:
    df3[columna] = pd.to_numeric(df3[columna], errors='coerce')  # 'coerce' convierte valores inválidos a NaN
    # Almacenar las filas con NaN en esa columna
    filas_no_convertidas = pd.concat([filas_no_convertidas, df3[df3[columna].isna()]])

# Eliminar las filas con NaN en las columnas especificadas
df3 = df3.dropna(subset=columnas_a_limpiar)

# Contar el número de filas después de la limpieza
num_filas_despues = len(df3)

# Calcular el número de filas eliminadas
filas_eliminadas = num_filas_antes - num_filas_despues

# Mostrar el número de filas eliminadas
print(f'Número de filas eliminadas: {filas_eliminadas}')
# Out:
# Número de filas eliminadas: 215

# %%
#Validar como salen las columnas
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1785 entries, 1 to 1999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nombre Entidad              1785 non-null   object
#  1   NIT                         1785 non-null   object
#  2   Año                         1785 non-null   int64
#  3   Presupuesto Total           1785 non-null   float64
#  4   Limite Menor Cuantia        1785 non-null   float64
#  5   Limite Minima Cuantia       1785 non-null   float64
#  6   Fecha ultima actualizacion  1778 non-null   object
#  7   Fecha de Cargue             1785 non-null   object
#  8   Municipio                   1785 non-null   object
#  9   Departamento                1785 non-null   object
#  10  NIT_length                  1785 non-null   int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 167.3+ KB

# %% [markdown]
# ## **Analisis y Graficos**

# %%
#presupuesto total por Año
presupuesto_total = df3.groupby(['Año'])['Presupuesto Total'].sum()
print(presupuesto_total)
# Out:
# Año
# 2016    1.829235e+12
# 2017    2.851170e+12
# 2018    1.703861e+12
# 2019    8.810886e+11
# 2020    3.148817e+12
# 2021    1.954725e+14
# 2022    2.228785e+14
# 2023    2.776436e+13
# 2024    8.108686e+13
# 2025    0.000000e+00
# Name: Presupuesto Total, dtype: float64

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\adm1n\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adm1n\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\adm1n\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Grafica por año
import matplotlib.pyplot as plt

data_agrupada = df3.groupby('Año')['Presupuesto Total'].sum()

# Crear la gráfica de barras
plt.figure(figsize=(7, 5))
data_agrupada.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Año')
plt.ylabel('Presupuesto Total')
plt.title('Presupuesto Total por Año')

# Mostrar la gráfica
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Se logra evidenciar que en el 2021, y 2022 fueron los años donde menos presupuesto total hubo

# %%
# Reemplazar 'Bogotá' por 'Bogotá D.C.' en la columna 'Ciudad'
df3['Departamento'] = df3['Departamento'].replace('Bogotá D.C.', 'Bogotá', regex=True)

#Presupuesto Total por Departamento
presupuesto_dep = df3.groupby(['Departamento'])['Presupuesto Total'].sum()
print(presupuesto_dep)
# Out:
# Departamento
# Amazonas                                    3.573975e+10
# Antioquia                                   1.705987e+14
# Arauca                                      4.295754e+12
# Atlántico                                   3.737842e+13
# Bogotá                                      2.547867e+11
# Bolívar                                     1.024687e+12
# Boyacá                                      2.559582e+13
# Caldas                                      3.426048e+12
# Caquetá                                     2.409279e+13
# Casanare                                    1.167152e+13
# Cauca                                       4.812904e+13
# Cesar                                       2.652798e+12
# Chocó                                       1.105303e+11
# Cundinamarca                                1.172554e+13
# Córdoba                                     9.833150e+11
# Distrito Capital de Bogotá                  6.710590e+13
# Guainía                                     4.003383e+10
# Guaviare                                    6.212575e+11
# Huila                                       5.115553e+12
# La Guajira                                  8.789181e+12
# Magdalena                                   2.483856e+12
# Meta                                        1.135029e+13
# Nariño                                      4.290439e+13
# No definido                                 1.276995e+11
# Norte De Santander                          5.170705e+10
# Norte de Santander                          3.566843e+11
# Putumayo                                    1.309103e+13
# Quindío                                     3.025315e+12
# Risaralda                                   1.061638e+13
# San Andrés, Providencia y Santa Catalina    5.966679e+10
# Santander                                   7.719012e+12
# Sucre                                       1.814369e+12
# Tolima                                      2.083357e+12
# Valle del Cauca                             1.825652e+13
# Vaupés                                      0.000000e+00
# Vichada                                     2.870902e+10
# Name: Presupuesto Total, dtype: float64

# %%
# Crear la gráfica de líneas
plt.figure(figsize=(25, 6))
plt.plot(presupuesto_dep.index, presupuesto_dep.values, marker='o', color='skyblue', linestyle='-', linewidth=2)

# Añadir etiquetas y título
plt.xlabel('Departamento')
plt.ylabel('Suma de Valores')
plt.title('Suma de Valores por Departamento')

# Mostrar la gráfica
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Se logra apreciar que la mayoria del presupuesto total pertenece a las empresas de antioquia

# %%
# Graficar una torta para el 2024
data_2024 = df3[df3['Año'] == 2024].iloc[0]
labels = ['Limite Minima Cuantia', 'Limite Menor Cuantia']
sizes = [data_2024['Limite Minima Cuantia'], data_2024['Limite Menor Cuantia']]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Configurar la gráfica
plt.title('Distribución del Presupuesto en 2024')

# Mostrar la gráfica
plt.show()

# %%
#Presupuesto mimina cuantia por Departamento
presupuesto_min = df3.groupby(['Departamento'])['Limite Minima Cuantia'].sum()

# Crear la gráfica de líneas
plt.figure(figsize=(25, 6))
plt.plot(presupuesto_min.index, presupuesto_min.values, marker='o', color='skyblue', linestyle='-', linewidth=2)

# Añadir etiquetas y título
plt.xlabel('Departamento')
plt.ylabel('Minima Cuantia')
plt.title('Minima cuantia por departamento')

# Mostrar la gráfica
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
print(presupuesto_min)
# Out:
# Departamento
# Amazonas                                    3.939880e+08
# Antioquia                                   2.705139e+10
# Arauca                                      8.469030e+08
# Atlántico                                   2.937756e+10
# Bogotá                                      9.936914e+08
# Bolívar                                     7.480959e+09
# Boyacá                                      1.276764e+10
# Caldas                                      2.394823e+09
# Caquetá                                     6.345210e+09
# Casanare                                    3.925554e+09
# Cauca                                       2.037933e+09
# Cesar                                       2.591970e+09
# Chocó                                       2.226042e+08
# Cundinamarca                                9.804971e+10
# Córdoba                                     2.000000e+36
# Distrito Capital de Bogotá                  4.417525e+11
# Guainía                                     5.800000e+08
# Guaviare                                    3.318032e+08
# Huila                                       5.748098e+10
# La Guajira                                  1.117022e+09
# Magdalena                                   1.220819e+09
# Meta                                        1.756658e+10
# Nariño                                      7.240536e+09
# No definido                                 1.000000e+08
# Norte De Santander                          2.705832e+08
# Norte de Santander                          8.499680e+08
# Putumayo                                    1.265181e+10
# Quindío                                     1.251106e+09
# Risaralda                                   1.801418e+10
# San Andrés, Providencia y Santa Catalina    2.905771e+09
# Santander                                   2.000000e+36
# Sucre                                       4.688686e+09
# Tolima                                      1.562512e+10
# Valle del Cauca                             6.971771e+09
# Vaupés                                      0.000000e+00
# Vichada                                     1.034559e+08
# Name: Limite Minima Cuantia, dtype: float64

# %%
#Presupuesto mimina cuantia por Departamento
presupuesto_men = df3.groupby(['Departamento'])['Limite Menor Cuantia'].sum()

# Crear la gráfica de líneas
plt.figure(figsize=(25, 6))
plt.plot(presupuesto_min.index, presupuesto_min.values, marker='o', color='skyblue', linestyle='-', linewidth=2)

# Añadir etiquetas y título
plt.xlabel('Departamento')
plt.ylabel('Minima men')
plt.title('Minima cuantia por departamento')

# Mostrar la gráfica
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
